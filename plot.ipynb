# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from helpers.data import X, trueFile

# %%
plt.rcParams["figure.figsize"] = (27,3)

print(X.shape)

start, end = 78800, 79200

for i in X:
    plt.plot(i[start:end])
plt.show()
print(np.min(X))
# Out:
# (29, 131072)
# -0.5958072864992512

# %%
# rec = pd.read_csv('recons_x.csv', header=None, index_col=False)
rec = pd.read_parquet('recons_x.parquet', engine='fastparquet')
rec = rec.transpose()
rec_X = rec.to_numpy()

# plt.plot(rec_X[1])
# print(rec_X.shape)
# plt.plot(rec_X)
for i,ele in enumerate(rec_X):
    plt.plot(ele[start:end])


# plt.plot(rec_X[2][start:end]-max(rec_X[2]))
# plt.legend()
plt.show()
